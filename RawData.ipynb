# %% [markdown]
# <a href="https://colab.research.google.com/github/tutur90/Weather-Forecast/blob/main/RawData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

dfs = []

for root, dirs, files in os.walk("data/data_rasa", ):
    for file in sorted(files):
        if file.endswith(".csv"):
            print(file[:-4])
            
            df = pd.read_csv(os.path.join(root, file), index_col=0)
            cols = []
            for df_col in df.columns:
                if df_col.startswith("Unnamed:"):
                    del df[df_col]
                else:
                    cols.append((file[:-4], df_col))
                    
            df.columns = pd.MultiIndex.from_tuples(cols)    
            dfs.append(df)
            
df = pd.concat(dfs,axis=
               1, join='outer',   )
df
# Out:
# 0002_Tola.Tumbaco
# 0003_Izobamba.SQuito
# 0005_Portoviejo.Manta
# 0007_Rocafuerte.Yasuni
# 0008_Puyo
# 0024_Quito
# 0037_Milagro
# 0153_Muisne
# 0156_Quininde
# 0162_Chone
# 0246_Chongon
# 1094_Tabacundo.Cayambe
# 1096_Guayaquil
# 1230_Espam.Calceta
# Ayora
# Bellavista
# M0001
# M0002
# M0003
# M0004
# M0005
# M0006
# M0007
# M0008
# M0009
# M0010
# M0023
# M0024
# M0025
# M0026
# M0029
# M0031
# M0032
# M0033
# M0037
# M0039
# M0041
# M0045
# M0046
# M0047
# M0050
# M0051
# M0070
# M0075
# M0082
# M0084
# M0086
# M0101
# M0102
# M0103
# M0104
# M0105
# M0106
# M0107
# M0110
# M0111
# M0112
# M0114
# M0115
# M0117
# M0118
# M0120
# M0121
# M0122
# M0123
# M0124
# M0126
# M0127
# M0128
# M0129
# M0130
# M0131
# M0132
# M0133
# M0134
# M0135
# M0136
# M0137
# M0138
# M0139
# M0140
# M0141
# M0142
# M0143
# M0144
# M0145
# M0146
# M0147
# M0148
# M0149
# M0150
# M0151
# M0153
# M0154
# M0156
# M0160
# M0162
# M0165
# M0166
# M0167
# M0168
# M0169
# M0170
# M0171
# M0172
# M0173
# ...

# %%
import missingno as msno    
msno.matrix(df)
# Out:
# <Axes: >

# %%
dfs
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import missingno as msno    

data = pd.read_csv("data/datos_unidos.csv", index_col='Date', parse_dates=True).drop(columns=['Unnamed: 0'])

new_cols = []

for col in data.columns:
    if len(col.split('_')) > 1:
        new_cols.append((col.split('_')[-2], col.split('_')[-1]))

    
data.columns = pd.MultiIndex.from_tuples(new_cols)

data
# Out:
# /tmp/ipykernel_27558/4146968734.py:6: DtypeWarning: Columns (30,152,153,332,333,356,357,404,405,428,429,432,433,701) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data/datos_unidos.csv", index_col='Date', parse_dates=True).drop(columns=['Unnamed: 0'])
#               Milagro                               Quininde            \
#            Total.Prec Mean.Temp Min.Temp Max.Temp Total.Prec Mean.Temp
# Date
# 1964-01-01        0.2       NaN      NaN      NaN       10.6       NaN
# 1964-01-02        0.1       NaN      NaN      NaN        1.5       NaN
# 1964-01-03        3.1       NaN      NaN      NaN        0.5       NaN
# 1964-01-04        0.0       NaN      NaN      NaN        8.3       NaN
# 1964-01-05        0.0       NaN      NaN      NaN        5.5       NaN
# ...               ...       ...      ...      ...        ...       ...
# 2023-04-29        NaN       NaN      NaN      NaN        NaN       NaN
# ...

# %%
names = data.columns.levels[1].unique()
print(names)
for name in names:
    msno.matrix(data.loc[:, pd.IndexSlice[:, name]])
    plt.show()
# Out:
# Index(['Max.Temp', 'Mean.Temp', 'Min.Temp', 'Total.Prec'], dtype='object')

# %%
resemple = data.fillna(method='ffill').resample('D').mean()

names = data.columns.levels[1].unique()
print(names)
for name in names:
    msno.matrix(resemple.loc[:, pd.IndexSlice[:, name]])
    plt.show()
# Out:
# /tmp/ipykernel_27558/4272994542.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   resemple = data.fillna(method='ffill').resample('D').mean()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# ...

# %%
for dfd in dfs:
    print(dfd.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for dfd in dfs:
#       2     print(dfd.index)
#
# NameError: name 'dfs' is not defined

# %%
df.to_csv("data/data_rasa.csv")

# %%
import missingno as msno
msno.matrix(df)
# Out:
# Le noyau s’est bloqué lors de l’exécution du code dans une cellule active ou une cellule précédente.
#
# Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec.
#
# Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
